# %%
import os
from src.mesh import Mesh

# %%
import sys

# %%
# %load_ext autoreload
# %autoreload 2

# %%
test = Mesh('rae2822', '../rae2822.dat', 1e-2, 1e-4, 3)
test.genPoints()
test.write('./teste.su2')

# %%
def create_mesh(name, file, size_ff, size_af, farfield_rad=5):
    test = Mesh('rae2822', file, size_ff, size_af, farfield=[10, 10])
    test.genPoints()
    test.write('./teste.geo_unrolled')

# %%
import pandas as pd

# %%
df = pd.read_csv('./tests/history.csv')

# %%
df.describe()
# Out:
#               "CD"                "CL"                "CSF"        \
# count              1000.0              1000.0              1000.0
# mean                  0.0                 0.0                 0.0
# std                   0.0                 0.0                 0.0
# min                   0.0                 0.0                 0.0
# 25%                   0.0                 0.0                 0.0
# 50%                   0.0                 0.0                 0.0
# 75%                   0.0                 0.0                 0.0
# max                   0.0                 0.0                 0.0
#
#               "CMx"               "CMy"               "CMz"        \
# count              1000.0              1000.0              1000.0
# mean                  0.0                 0.0                 0.0
# std                   0.0                 0.0                 0.0
# min                   0.0                 0.0                 0.0
# 25%                   0.0                 0.0                 0.0
# 50%                   0.0                 0.0                 0.0
# 75%                   0.0                 0.0                 0.0
# max                   0.0                 0.0                 0.0
#
#               "CFx"               "CFy"               "CFz"        \
# count              1000.0              1000.0              1000.0
# mean                  0.0                 0.0                 0.0
# std                   0.0                 0.0                 0.0
# min                   0.0                 0.0                 0.0
# 25%                   0.0                 0.0                 0.0
# 50%                   0.0                 0.0                 0.0
# 75%                   0.0                 0.0                 0.0
# max                   0.0                 0.0                 0.0
#
#              "CEff"
# count              1000.0
# mean                  0.0
# std                   0.0
# min                   0.0
# 25%                   0.0
# 50%                   0.0
# 75%                   0.0
# max                   0.0
